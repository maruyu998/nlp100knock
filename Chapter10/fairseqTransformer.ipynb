# %%
import pickle
with open('model_logs/ja_dic.pickle', 'rb') as f: ja_dic = pickle.load(f)
with open('model_logs/en_dic.pickle', 'rb') as f: en_dic = pickle.load(f)

# %%
from fairseq.data.dictionary import Dictionary

# %%
def get_fairseq_dict(dic:dict):
    f_dic = Dictionary(pad="[PAD]", eos="[EOS]", unk="[UNK]", bos="[BOS]")
    for w, i in dic.items(): f_dic.add_symbol(w,i)
    return f_dic

# %%
f_dic_ja = get_fairseq_dict(ja_dic)
f_dic_en = get_fairseq_dict(en_dic)
ja_embdim = max(ja_dic.values())+1
en_embdim = max(en_dic.values())+1
print(ja_embdim, en_embdim)
# Out:
# 23767 20176

# %% [markdown]
# ----

# %%
from fairseq.models.transformer import TransformerModel, TransformerEncoder, TransformerDecoder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# めんどくさい
from fairseq.models import transformer_parser
args = transformer_parser.parse_args([])
# from fairseq.tasks.translation import TranslationTask
# transformer_parser.conflict_handler='resolve'
# print(transformer_parser)
# TranslationTask.add_args(transformer_parser)
# args = transformer_parser.parse_args(['--dropout', '0.1'], args)
# args = transformer_parser.parse_args(['--encoder-layerdrop', '0.1'], args)

# %%
print(*args._get_kwargs(),sep=",")
# Out:
# ('activation_dropout', None),('activation_fn', None),('adaptive_softmax_cutoff', None),('adaptive_softmax_dropout', None),('arch', None),('attention_dropout', None),('cross_self_attention', False),('decoder_attention_heads', None),('decoder_embed_dim', None),('decoder_embed_path', None),('decoder_ffn_embed_dim', None),('decoder_layerdrop', 0),('decoder_layers', None),('decoder_layers_to_keep', None),('decoder_learned_pos', False),('decoder_normalize_before', False),('dropout', None),('encoder_attention_heads', None),('encoder_embed_dim', None),('encoder_embed_path', None),('encoder_ffn_embed_dim', None),('encoder_layerdrop', 0),('encoder_layers', None),('encoder_layers_to_keep', None),('encoder_learned_pos', False),('encoder_normalize_before', False),('layer_wise_attention', False),('layernorm_embedding', False),('no_cross_attention', False),('no_scale_embedding', False),('no_token_positional_embeddings', False),('share_all_embeddings', False),('share_decoder_input_output_embed', False)

# %%
class transformer_params(dict): 
    def __init__(self, *args, **kwargs):
        from fairseq.models import transformer_parser
        default = transformer_parser.parse_args([]).__dict__
        default.update(args[0])
        kwargs.update(default)
        kwargs['max_source_positions'] = 1024
        kwargs['max_target_positions'] = 1024
        super().__init__(*args, **kwargs)
        self.__dict__ = self

# %%
args = transformer_params({'dropout':0.1,
                          'encoder_layerdrop':0.1,
#                           'no_scale_embedding': False,
#                           'no_token_positional_embeddings': False,
#                           'encoder_learned_pos':False,
                           'encoder_layers':6,
                           'encoder_embed_dim':512,
                           'encoder_attention_heads':8, # must be a divisor of encoder_embed_dim
                           'attention_dropout':0.1,
                           'encoder_normalize_before':True,
                           'encoder_ffn_embed_dim':2048,
                           'decoder_layerdrop':0.1,
                           'share_decoder_input_output_embed':True,
                           'decoder_embed_dim':512,
                           'decoder_output_dim':en_embdim,
                           'decoder_learned_pos':False,
                           'decoder_layers':6,
                           'decoder_attention_heads':8,
                           'decoder_normalize_before':True,
                           'decoder_ffn_embed_dim':2048, 
                           'tie_adaptive_weights':True,
                           'activation_fn':'relu',
                           'activation_dropout':0.1
                        })

# %%
class FairseqModel(nn.Module):
    def __init__(self):
        super().__init__()
        ja_emb = nn.Embedding(num_embeddings=ja_embdim, embedding_dim=512, padding_idx=0)
        en_emb = nn.Embedding(num_embeddings=en_embdim, embedding_dim=512, padding_idx=0)
        encoder = TransformerEncoder(args=args, dictionary=f_dic_ja, embed_tokens=ja_emb)
        decoder = TransformerDecoder(args=args, dictionary=f_dic_en, embed_tokens=en_emb)
        self.model = TransformerModel(args, encoder, decoder)
        from fastai.text import CrossEntropyFlat
        self.criterion = CrossEntropyFlat(ignore_index=0)
    
    def predict(self, ja_seq, en_seq, *, mask=True):
        pred = self.model(ja_seq, torch.sum(ja_seq!=0, dim=1), en_seq)[0]
        return pred
    
    def loss(self, pred, en_ans):
        batch_size, length = en_ans.shape[0], en_ans.shape[1]
        ### train data:   eg. [BOS] I am a ... [EOS] [PAD] ###
        ### ground truth: eg. I am a ... [EOS] [PAD] [PAD] ###
        with torch.no_grad():
            accuracy = float(torch.sum((pred.argmax(dim=2)==en_ans) * (en_ans!=0)))/float(torch.sum(en_ans!=0))
        
        loss = self.criterion(pred, en_ans)
        return loss, accuracy
    
    def forward(self, ja_seq, en_seq, en_ans):
        pred = self.predict(ja_seq, en_seq)
        return self.loss(pred, en_ans)

# %%
params = {}
params['embdim'] = 512
params['batch_size'] =64*2
params['warmup_steps'] = 4000
params['lrate_coef'] = 25000/params['batch_size']
params['cuda_optim'] = False
params['embinit'] = False

# %%
model = FairseqModel().float()
optimizer = optim.Adam(model.parameters(),betas=(0.9, 0.98), eps=1e-09)
lrate_lambda = lambda step_num: params['embdim']**(-0.5)*params['lrate_coef']*min((step_num+1)**(-0.5), (step_num+1)*params['warmup_steps']**(-1.5))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lrate_lambda])
device = torch.device("cuda:8" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
print(device)
print(sum(p.numel() for p in model.parameters()))
# Out:
# cuda:8
# 66639360

# %%
from Chapter10_91 import DataSet, Translator, Trainer
translator = Translator(ja_dic, en_dic)
trainset = DataSet("train", maxlength=60, pathkey="ids")
devset = DataSet("dev", maxlength=60, pathkey="ids")

# %%
from string import ascii_letters
from random import choices
from Chapter10_91 import EarlyStopping, Save, Tensorboard, BleuCallback, Print
examples = ["私以外私じゃないの", "私は猫です。", "日本の水墨画を一変させた。"]
translator = Translator(ja_dic, en_dic)

bleu_cb = BleuCallback(lambda seq: " ".join([translator.en_dic_rev[s] if s!=12 else ''.join(choices(ascii_letters,k=5)) for s in seq]))
es_cb = EarlyStopping(count=10)
save_cb = Save(model,'model_logs/fairseq')
tb_cb = Tensorboard('./tb_logs/', 'fairseq_91', bleu_cb)
print_cb = Print(model, translator, device, examples=examples, early_stopping=es_cb, bleu_callback=bleu_cb)
callbacks = [es_cb,bleu_cb,save_cb,tb_cb,print_cb]
# Out:
# savedir:model_logs/fairseq_20200804_142746
# tensorboard tagname: 20200804_142749_fairseq_91

# %%
trainer = Trainer(translator, trainset, devset, device=device)
trainer.run(model, optimizer, epoch=300, device=device, batch_size=params['batch_size'], shuffle=True, scheduler=scheduler, callbacks=callbacks)
# Out:
# >10[  1/300]epoch: loss: 78.3105287, 7.3106433 | acc: 5.58691%, 15.89397% | bleu: 0.08098
#    私以外私じゃないの　　　　	[UNK] . [EOS]
#    私は猫です。　　　　　　　	[UNK] . [EOS]
#    日本の水墨画を一変させた。	[UNK] . [EOS]
# >10[  2/300]epoch: loss: 7.3614282, 5.9120545 | acc: 12.69357%, 21.00773% | bleu: 0.56890
#    私以外私じゃないの　　　　	[UNK] ( [UNK] ) [EOS]
#    私は猫です。　　　　　　　	[UNK] . [EOS]
#    日本の水墨画を一変させた。	He was the [UNK] . [EOS]
# >10[  3/300]epoch: loss: 6.4479790, 5.6665649 | acc: 16.78947%, 22.76005% | bleu: 0.61845
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	He was the [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] . [EOS]
# >10[  4/300]epoch: loss: 5.9410471, 5.4402046 | acc: 20.05725%, 25.29055% | bleu: 1.58508
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	His name was [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] . [EOS]
# >10[  5/300]epoch: loss: 5.5207765, 5.2880964 | acc: 22.86878%, 25.99651% | bleu: 2.13219
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	His name was [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] . [EOS]
# >10[  6/300]epoch: loss: 5.2538937, 5.1680281 | acc: 24.74210%, 27.07460% | bleu: 2.41070
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	His name was [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that Japan in Japan . [EOS]
# >10[  7/300]epoch: loss: 5.0923319, 5.0486241 | acc: 25.96056%, 27.71620% | bleu: 2.76139
#    私以外私じゃないの　　　　	[UNK] ( [UNK] ) [EOS]
#    私は猫です。　　　　　　　	His name was [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] in Japan . [EOS]
# >10[  8/300]epoch: loss: 4.9645637, 4.9590265 | acc: 26.92545%, 27.98285% | bleu: 2.87493
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	The name is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the name of Japan . [EOS]
# >10[  9/300]epoch: loss: 4.8714151, 4.8711422 | acc: 27.59606%, 28.51490% | bleu: 3.09136
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] in Japan . [EOS]
# >10[ 10/300]epoch: loss: 4.7833862, 4.7924495 | acc: 28.25084%, 29.25276% | bleu: 3.33748
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] in Japan . [EOS]
# >10[ 11/300]epoch: loss: 4.7078164, 4.7367191 | acc: 28.80900%, 29.79505% | bleu: 3.56809
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	His real name was [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is said that the [UNK] of Japan in Japan . [EOS]
# >10[ 12/300]epoch: loss: 4.6472947, 4.6704605 | acc: 29.32018%, 30.39478% | bleu: 3.63516
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , the [UNK] of Japan . [EOS]
# >10[ 13/300]epoch: loss: 4.5860971, 4.6226823 | acc: 29.70057%, 30.65094% | bleu: 3.71835
#    私以外私じゃないの　　　　	In addition , there are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , the [UNK] of Japan . [EOS]
# >10[ 14/300]epoch: loss: 4.5239806, 4.5674888 | acc: 30.22914%, 30.90396% | bleu: 3.92876
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , it is a [UNK] . [EOS]
# >10[ 15/300]epoch: loss: 4.4751127, 4.5320447 | acc: 30.62167%, 31.05287% | bleu: 4.02927
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , it was made by [UNK] . [EOS]
# >10[ 16/300]epoch: loss: 4.4317329, 4.4873196 | acc: 30.97319%, 31.51932% | bleu: 4.17196
#    私以外私じゃないの　　　　	[UNK] ( [UNK] ) [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] ( Japanese style style ) . [EOS]
# >10[ 17/300]epoch: loss: 4.3811079, 4.4390270 | acc: 31.38607%, 31.78734% | bleu: 4.41773
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] ( Japanese [UNK] ) . [EOS]
# >10[ 18/300]epoch: loss: 4.3455049, 4.4091019 | acc: 31.66974%, 31.97111% | bleu: 4.65279
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] . [EOS]
# >10[ 19/300]epoch: loss: 4.3143269, 4.3773407 | acc: 31.92284%, 32.26856% | bleu: 4.74741
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] ( Japanese [UNK] ) . [EOS]
# >10[ 20/300]epoch: loss: 4.2793935, 4.3425285 | acc: 32.20149%, 32.47553% | bleu: 4.79249
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] of Japanese music . [EOS]
# >10[ 21/300]epoch: loss: 4.2452024, 4.3138921 | acc: 32.50364%, 32.68701% | bleu: 4.87107
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It was made of Japanese music . [EOS]
# >10[ 22/300]epoch: loss: 4.2167512, 4.2862990 | acc: 32.71521%, 32.80230% | bleu: 4.87607
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It was made by Japanese music . [EOS]
# >10[ 23/300]epoch: loss: 4.1880422, 4.2583916 | acc: 32.97192%, 33.17064% | bleu: 4.91112
#    私以外私じゃないの　　　　	In addition , there are not only . [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It was made by Japanese music . [EOS]
# >10[ 24/300]epoch: loss: 4.1601377, 4.2329871 | acc: 33.19104%, 33.31230% | bleu: 5.26169
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he [UNK] ( Japanese music ) of Japanese music . [EOS]
# >10[ 25/300]epoch: loss: 4.1387865, 4.2176343 | acc: 33.44713%, 33.19595% | bleu: 5.25801
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	It was made by Japanese music . [EOS]
# >10[ 26/300]epoch: loss: 4.1116531, 4.2042177 | acc: 33.61569%, 33.59782% | bleu: 5.25790
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he [UNK] ( Japanese music ) of Japanese music . [EOS]
# >10[ 27/300]epoch: loss: 4.0924201, 4.1769731 | acc: 33.82324%, 33.76625% | bleu: 5.31316
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a Japanese music of Japanese music . [EOS]
# >10[ 28/300]epoch: loss: 4.0614748, 4.1512998 | acc: 34.06606%, 33.69880% | bleu: 5.49280
#    私以外私じゃないの　　　　	In addition , there is no [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a Japanese - style style style style style style style style style style style style style style style style .
# >10[ 29/300]epoch: loss: 4.0503414, 4.1373558 | acc: 34.15573%, 34.04453% | bleu: 5.41052
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is not [UNK] . [EOS]
#    日本の水墨画を一変させた。	In Japan , he made a [UNK] ( Japanese music ) of Japanese music . [EOS]
# >10[ 30/300]epoch: loss: 4.0197843, 4.1235338 | acc: 34.47567%, 34.13433% | bleu: 5.49445
#    私以外私じゃないの　　　　	In addition , there is no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese music . [EOS]
# >10[ 31/300]epoch: loss: 4.0040596, 4.1008580 | acc: 34.55436%, 34.25554% | bleu: 5.59317
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 32/300]epoch: loss: 3.9841039, 4.0816610 | acc: 34.72696%, 34.27883% | bleu: 5.53504
#    私以外私じゃないの　　　　	In addition , there is no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese tea ceremony in Japan . [EOS]
# >10[ 33/300]epoch: loss: 3.9711145, 4.0713782 | acc: 34.79970%, 34.44462% | bleu: 5.69661
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese music . [EOS]
# >10[ 34/300]epoch: loss: 3.9481709, 4.0522585 | acc: 35.09207%, 34.59283% | bleu: 5.96443
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 35/300]epoch: loss: 3.9339683, 4.0410684 | acc: 35.23341%, 34.62981% | bleu: 6.09554
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	It is [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 36/300]epoch: loss: 3.9143462, 4.0276792 | acc: 35.32724%, 34.72876% | bleu: 6.09191
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 37/300]epoch: loss: 3.8942580, 4.0191620 | acc: 35.51833%, 34.80632% | bleu: 5.95952
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 38/300]epoch: loss: 3.8887779, 4.0040125 | acc: 35.66720%, 34.75741% | bleu: 5.67661
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made a Japanese style of Japanese music . [EOS]
# >10[ 39/300]epoch: loss: 3.8666282, 3.9842097 | acc: 35.77846%, 35.19040% | bleu: 6.06626
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese music . [EOS]
# >10[ 40/300]epoch: loss: 3.8620730, 3.9695464 | acc: 35.88966%, 35.09399% | bleu: 6.08653
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese painting . [EOS]
# >10[ 41/300]epoch: loss: 3.8281221, 3.9581636 | acc: 36.15782%, 35.23454% | bleu: 6.14247
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese painting . [EOS]
# >10[ 42/300]epoch: loss: 3.8208911, 3.9486623 | acc: 36.21852%, 35.37130% | bleu: 6.27027
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese painting . [EOS]
# >10[ 43/300]epoch: loss: 3.7961588, 3.9374920 | acc: 36.43052%, 35.69477% | bleu: 6.62324
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese painting . [EOS]
# >10[ 44/300]epoch: loss: 3.7887530, 3.9239668 | acc: 36.45928%, 35.68643% | bleu: 6.48796
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese - style painting . [EOS]
# >10[ 45/300]epoch: loss: 3.7697964, 3.9146764 | acc: 36.65120%, 35.71717% | bleu: 6.60221
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese - style painting . [EOS]
# >10[ 46/300]epoch: loss: 3.7649923, 3.9043062 | acc: 36.71540%, 35.85681% | bleu: 6.27288
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese - style painting . [EOS]
# >10[ 47/300]epoch: loss: 3.7484237, 3.8796979 | acc: 36.83494%, 36.12071% | bleu: 6.66429
#    私以外私じゃないの　　　　	[UNK] [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 48/300]epoch: loss: 3.7356687, 3.8781666 | acc: 36.95852%, 36.03333% | bleu: 6.63155
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 49/300]epoch: loss: 3.7209807, 3.8672850 | acc: 37.12426%, 36.14687% | bleu: 6.68627
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese style of Japanese - style painting . [EOS]
# >10[ 50/300]epoch: loss: 3.7168538, 3.8607589 | acc: 37.22684%, 36.06662% | bleu: 6.83908
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 51/300]epoch: loss: 3.7041586, 3.8496623 | acc: 37.24044%, 36.50248% | bleu: 7.04070
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 52/300]epoch: loss: 3.6824608, 3.8418630 | acc: 37.47135%, 36.45654% | bleu: 7.11513
#    私以外私じゃないの　　　　	There are no [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 53/300]epoch: loss: 3.6776260, 3.8249718 | acc: 37.51282%, 36.63975% | bleu: 7.03811
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 54/300]epoch: loss: 3.6629234, 3.8165296 | acc: 37.70955%, 36.49259% | bleu: 7.08854
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 55/300]epoch: loss: 3.6488645, 3.8081159 | acc: 37.74835%, 36.45547% | bleu: 7.29682
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 56/300]epoch: loss: 3.6384555, 3.7979941 | acc: 37.83559%, 36.72265% | bleu: 6.94858
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I have you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 57/300]epoch: loss: 3.6355970, 3.7873953 | acc: 37.89192%, 36.76378% | bleu: 7.10070
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	There is no [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 58/300]epoch: loss: 3.6176508, 3.7746756 | acc: 38.04638%, 36.79320% | bleu: 7.10596
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I have you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   9[ 59/300]epoch: loss: 3.6139466, 3.7749876 | acc: 38.06338%, 36.81064% | bleu: 7.05512
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 60/300]epoch: loss: 3.6044634, 3.7700571 | acc: 38.11281%, 36.73110% | bleu: 6.97112
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 61/300]epoch: loss: 3.5924871, 3.7547301 | acc: 38.28424%, 37.00304% | bleu: 7.10129
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that I do not [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 62/300]epoch: loss: 3.5811578, 3.7484956 | acc: 38.35530%, 37.03008% | bleu: 7.26741
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 63/300]epoch: loss: 3.5693931, 3.7319949 | acc: 38.45073%, 37.01403% | bleu: 7.23886
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
#   9[ 64/300]epoch: loss: 3.5735940, 3.7375656 | acc: 38.55684%, 37.02635% | bleu: 7.28490
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 65/300]epoch: loss: 3.5465232, 3.7230512 | acc: 38.70202%, 37.29557% | bleu: 7.40419
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 66/300]epoch: loss: 3.5393539, 3.7154660 | acc: 38.78914%, 37.42674% | bleu: 7.49312
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I have you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 67/300]epoch: loss: 3.5343670, 3.7107705 | acc: 38.75061%, 37.47558% | bleu: 7.50940
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I have you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 68/300]epoch: loss: 3.5241050, 3.7025667 | acc: 38.94825%, 37.39781% | bleu: 7.80506
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 69/300]epoch: loss: 3.5110497, 3.6949883 | acc: 39.01006%, 37.57229% | bleu: 7.67479
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you do not [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 70/300]epoch: loss: 3.5032234, 3.6845722 | acc: 39.07477%, 37.65042% | bleu: 7.73327
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
#   9[ 71/300]epoch: loss: 3.4933505, 3.6859719 | acc: 39.28276%, 37.44326% | bleu: 7.37130
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I have you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 72/300]epoch: loss: 3.4961459, 3.6724671 | acc: 39.30694%, 37.59411% | bleu: 7.56010
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you do not [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 73/300]epoch: loss: 3.4921741, 3.6639408 | acc: 39.28658%, 37.77459% | bleu: 7.73774
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I do n't do you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 74/300]epoch: loss: 3.4660728, 3.6555883 | acc: 39.44158%, 37.71929% | bleu: 7.58460
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I do n't do you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
#   9[ 75/300]epoch: loss: 3.4621264, 3.6602673 | acc: 39.46422%, 37.88073% | bleu: 7.95681
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 76/300]epoch: loss: 3.4509656, 3.6506660 | acc: 39.57485%, 37.84338% | bleu: 7.62556
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	It is said that you should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 77/300]epoch: loss: 3.4458400, 3.6393940 | acc: 39.66517%, 38.01430% | bleu: 8.12700
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 78/300]epoch: loss: 3.4361353, 3.6294308 | acc: 39.71008%, 38.05758% | bleu: 8.02994
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 79/300]epoch: loss: 3.4442307, 3.6284130 | acc: 39.70035%, 37.97565% | bleu: 7.88596
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	It is said that you do not [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 80/300]epoch: loss: 3.4210052, 3.6253991 | acc: 39.84155%, 38.08407% | bleu: 7.98738
#    私以外私じゃないの　　　　	There are no other than [UNK] . [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
# >10[ 81/300]epoch: loss: 3.4146070, 3.6204741 | acc: 39.93567%, 38.03801% | bleu: 7.75550
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting of Japanese - style painting . [EOS]
#   9[ 82/300]epoch: loss: 3.4100105, 3.6204768 | acc: 40.01253%, 38.01733% | bleu: 7.89817
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 83/300]epoch: loss: 3.4081574, 3.6062609 | acc: 40.05954%, 38.15391% | bleu: 7.97025
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 84/300]epoch: loss: 3.4088820, 3.6037035 | acc: 40.14097%, 38.25405% | bleu: 7.90907
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 85/300]epoch: loss: 3.3836554, 3.5932441 | acc: 40.23213%, 38.27729% | bleu: 8.10591
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   9[ 86/300]epoch: loss: 3.3779263, 3.5937552 | acc: 40.25417%, 38.20396% | bleu: 7.95435
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   8[ 87/300]epoch: loss: 3.3711878, 3.5939194 | acc: 40.43189%, 38.35324% | bleu: 8.29201
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 88/300]epoch: loss: 3.3646771, 3.5897532 | acc: 40.39205%, 38.22336% | bleu: 8.21386
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 89/300]epoch: loss: 3.3556291, 3.5805462 | acc: 40.53789%, 38.41835% | bleu: 8.33773
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 90/300]epoch: loss: 3.3492589, 3.5775378 | acc: 40.52204%, 38.41468% | bleu: 8.17052
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 91/300]epoch: loss: 3.3409387, 3.5733056 | acc: 40.60435%, 38.46326% | bleu: 8.43293
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 92/300]epoch: loss: 3.3363560, 3.5641204 | acc: 40.64571%, 38.62997% | bleu: 8.45328
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	I do you you you you . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 93/300]epoch: loss: 3.3283498, 3.5633240 | acc: 40.72598%, 38.65322% | bleu: 8.54169
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 94/300]epoch: loss: 3.3175215, 3.5572104 | acc: 40.86064%, 38.67597% | bleu: 8.55281
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 95/300]epoch: loss: 3.3140629, 3.5539838 | acc: 40.91233%, 38.67069% | bleu: 8.16874
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 96/300]epoch: loss: 3.3080181, 3.5399292 | acc: 40.91055%, 38.70940% | bleu: 8.49992
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 97/300]epoch: loss: 3.3057977, 3.5356949 | acc: 40.98353%, 38.97027% | bleu: 8.40058
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[ 98/300]epoch: loss: 3.2955412, 3.5301357 | acc: 41.04063%, 38.89113% | bleu: 8.38326
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   9[ 99/300]epoch: loss: 3.2918575, 3.5359124 | acc: 41.09399%, 38.82172% | bleu: 8.44673
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   8[100/300]epoch: loss: 3.2896522, 3.5365117 | acc: 41.07621%, 38.90686% | bleu: 8.64247
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[101/300]epoch: loss: 3.2730276, 3.5237995 | acc: 41.26236%, 38.87416% | bleu: 8.66285
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	[UNK] [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[102/300]epoch: loss: 3.2870502, 3.5106835 | acc: 41.31915%, 38.97653% | bleu: 8.58671
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[103/300]epoch: loss: 3.2638145, 3.5076226 | acc: 41.35781%, 38.99284% | bleu: 8.78505
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   9[104/300]epoch: loss: 3.2587828, 3.5097069 | acc: 41.38009%, 38.86492% | bleu: 8.38724
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - wash painting in Japan . [EOS]
# >10[105/300]epoch: loss: 3.2570148, 3.5060611 | acc: 41.38231%, 39.01561% | bleu: 8.50923
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
# >10[106/300]epoch: loss: 3.2453668, 3.5001435 | acc: 41.50205%, 39.03744% | bleu: 8.57230
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
#   9[107/300]epoch: loss: 3.2422894, 3.5036102 | acc: 41.57698%, 39.09395% | bleu: 8.55325
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - wash painting in Japan . [EOS]
# >10[108/300]epoch: loss: 3.2428480, 3.4935454 | acc: 41.56930%, 39.04587% | bleu: 8.62118
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
# >10[109/300]epoch: loss: 3.2369630, 3.4900476 | acc: 41.61275%, 39.23154% | bleu: 8.76573
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - style painting in Japan . [EOS]
# >10[110/300]epoch: loss: 3.2249657, 3.4872537 | acc: 41.70930%, 39.14308% | bleu: 8.82878
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - wash painting in Japan . [EOS]
# >10[111/300]epoch: loss: 3.2175692, 3.4719781 | acc: 41.77001%, 39.18326% | bleu: 8.73698
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	It is a Japanese - wash painting in Japan . [EOS]
#   9[112/300]epoch: loss: 3.2152282, 3.4773054 | acc: 41.79820%, 39.10697% | bleu: 8.57719
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
#   8[113/300]epoch: loss: 3.2051786, 3.4782762 | acc: 41.91717%, 39.26700% | bleu: 8.84587
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
#   7[114/300]epoch: loss: 3.2025171, 3.4727958 | acc: 41.91208%, 39.26566% | bleu: 8.81731
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[115/300]epoch: loss: 3.2030990, 3.4679297 | acc: 41.94394%, 39.35823% | bleu: 8.93625
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[116/300]epoch: loss: 3.1927352, 3.4671725 | acc: 42.04549%, 39.31751% | bleu: 8.78560
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[117/300]epoch: loss: 3.1871465, 3.4641996 | acc: 42.09755%, 39.37483% | bleu: 8.95269
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[118/300]epoch: loss: 3.1786633, 3.4639628 | acc: 42.21063%, 39.43177% | bleu: 8.84279
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[119/300]epoch: loss: 3.1793366, 3.4542910 | acc: 42.11961%, 39.60482% | bleu: 9.01350
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
#   9[120/300]epoch: loss: 3.1683592, 3.4581917 | acc: 42.28937%, 39.50211% | bleu: 8.87413
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
# >10[121/300]epoch: loss: 3.1607759, 3.4518501 | acc: 42.35792%, 39.50033% | bleu: 8.92869
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
# >10[122/300]epoch: loss: 3.1563178, 3.4518027 | acc: 42.40706%, 39.56974% | bleu: 8.97961
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You should be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
# >10[123/300]epoch: loss: 3.1517594, 3.4427500 | acc: 42.44011%, 39.62609% | bleu: 8.94748
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink painting . [EOS]
# [124/300]epoch [1193/3163]steps:[ja:60|en:59] loss: 0.0252989 | acc: 41.22473%
#    私以外私じゃないの　　　　	[UNK] other than [UNK] [EOS]
#    私は猫です。　　　　　　　	You will be [UNK] . [EOS]
#    日本の水墨画を一変させた。	He made Japanese ink - wash painting . [EOS]
